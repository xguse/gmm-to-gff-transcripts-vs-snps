# %% [markdown]
# # Prep

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Paths

# %%
linked_ = '../data/processed/gmm_to_gff_testing_filterPSL_100bp_local/get_nearest_k_features/OT.linked.snps_in_features.xls'
orig_ = '../data/processed/gmm_to_gff_testing_filterPSL_100bp_local/get_nearest_k_features/OT.original.snps_in_features.xls'

# %% [markdown]
# ## Constants

# %%
distance = 5000

# %% [markdown]
# ## Functions

# %%
def filter_by_distance(df, d=5000):
    return df.query(""" abs(distance) <= {d} """.format(d=d))

def set_comparison_table(a, b, a_name=None, b_name=None):
    a = set(a)
    b = set(b)
    
    data = [pd.Series((sorted(list(a & b))),name='{a} AND {b}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(a - b))),name='{a} NOT {b}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(b - a))),name='{b} NOT {a}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(a | b))),name='{a} OR {b}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(a ^ b))),name='one OR other NOT both'),]
    
    df = pd.DataFrame(data).T
    counts = pd.DataFrame(df.count(),columns=['count'])
    
    return {'genes':df, 'counts':counts}

# %% [markdown]
# ## Loading

# %%
linked = pd.read_excel(linked_)
orig = pd.read_excel(orig_)

# %%
linked.head()
# Out:
#      SNP_chrom  SNP_start  SNP_end feature_set_name        chrom  chromStart  \
# 0  Scaffold106     349186   349187  novel_mapped_tx  Scaffold106      320040
# 1  Scaffold106     349186   349187  novel_mapped_tx  Scaffold106      319095
# 2  Scaffold106     349186   349187  novel_mapped_tx  Scaffold106      383136
# 3  Scaffold106     349186   349187  novel_mapped_tx  Scaffold106      383136
# 4  Scaffold106     349186   349187  novel_mapped_tx  Scaffold106      405951
#
#    chromEnd            name  score strand  thickStart  thickEnd itemRgb  \
# 0    320102  TCONS_00083698      0      +      319095    320102   0,0,0
# 1    319104  TCONS_00083698      0      +      319095    320102   0,0,0
# 2    402324  TCONS_00083693      0      +      383136    587072   0,0,0
# 3    402324  TCONS_00083694      0      +      383136    587072   0,0,0
# 4    433030  TCONS_00083688      0      +      403014    584462   0,0,0
#
#    blockCount                                         blockSizes  \
# 0           3                                        481,465,40,
# 1           3                                        481,465,40,
# 2          33  74,156,55,158,82,47,6,72,141,38,113,83,210,5,6...
# 3          33  74,156,55,158,82,47,6,72,141,38,113,83,210,5,6...
# 4          23  7,72,141,38,113,83,210,5,63,82,184,95,5,159,89...
#
#                                          blockStarts  distance
# 0                              319095,319597,320062,    -29085
# 1                              319095,319597,320062,    -30083
# 2  383136,383424,383583,383638,383796,383878,4030...     33950
# 3  383136,383424,383583,383638,383796,383878,4030...     33950
# 4  403014,403022,403095,403236,403274,403387,4034...     56765

# %%
orig.head()
# Out:
#       SNP_chrom  SNP_start  SNP_end feature_set_name      chrom  chromStart  \
# 0  JFJR01012925       2544     2545                .          .          -1
# 1     Scaffold1    2237686  2237687  novel_mapped_tx  Scaffold1     2226915
# 2     Scaffold1    2237686  2237687  novel_mapped_tx  Scaffold1     2268286
# 3     Scaffold1    2237686  2237687  novel_mapped_tx  Scaffold1     2144078
# 4     Scaffold1    2237686  2237687  novel_mapped_tx  Scaffold1     2365004
#
#    chromEnd            name  score strand thickStart thickEnd itemRgb  \
# 0        -1               .     -1      .          .        .       .
# 1   2227788  TCONS_00023667      0      -    2226915  2227788   0,0,0
# 2   2268509  TCONS_00023697      0      +    2268286  2268509   0,0,0
# 3   2165341  TCONS_00038064      0      -    2144078  2165341   0,0,0
# 4   2365581  TCONS_00071717      0      -    2365004  2365581   0,0,0
#
#   blockCount                                  blockSizes  \
# 0          .                                           .
# 1          4                            216,114,281,260,
# 2          3                                  52,16,140,
# 3         15  60,11,41,73,101,19,12,17,80,99,6,6,7,7,49,
# 4         11           55,21,49,21,48,55,4,153,13,5,115,
#
#                                          blockStarts  distance
# 0                                                  .        -1
# 1                   2226915,2227133,2227247,2227528,     -9899
# 2                           2268286,2268345,2268369,     30600
# 3  2144078,2164656,2164669,2164712,2164785,216488...    -72346
# 4  2365004,2365062,2365083,2365134,2365161,236521...    127318

# %% [markdown]
# ## Cleaning

# %%
linked_wk = filter_by_distance(df=linked, d=distance)
orig_wk = filter_by_distance(df=orig, d=distance)

# %%
linked_wk.shape
# Out:
# (32, 17)

# %%
orig_wk.shape
# Out:
# (39, 17)

# %% [markdown]
# # Comparisons

# %%
# get sets of gene names to compare

linked_wk_official_genes = set(linked_wk.query(""" feature_set_name == 'official_annotations' """).name)
linked_wk_novel_tx = set(linked_wk.query(""" feature_set_name == 'novel_mapped_tx' """).name)

orig_wk_official_genes = set(orig_wk.query(""" feature_set_name == 'official_annotations' """).name)
orig_wk_novel_tx = set(orig_wk.query(""" feature_set_name == 'novel_mapped_tx' """).name)

# %% [markdown]
# ## Official Genes

# %%
official = set_comparison_table(a=linked_wk_official_genes, 
                                b=orig_wk_official_genes,
                                a_name="linked", 
                                b_name="original")

# %%
official['counts']
# Out:
#                        count
# linked AND original        0
# linked NOT original       11
# original NOT linked       13
# linked OR original        24
# one OR other NOT both     24

# %%
official['genes']
# Out:
#    linked AND original linked NOT original original NOT linked  \
# 0                  NaN          GFUI002898          GFUI002713
# 1                  NaN          GFUI008017          GFUI007441
# 2                  NaN          GFUI008024          GFUI008496
# 3                  NaN          GFUI017734          GFUI011907
# 4                  NaN          GFUI021833          GFUI026687
# 5                  NaN          GFUI021834          GFUI026699
# 6                  NaN          GFUI021857          GFUI029720
# 7                  NaN          GFUI024278          GFUI030741
# 8                  NaN          GFUI028910          GFUI030748
# 9                  NaN          GFUI030827          GFUI035775
# 10                 NaN          GFUI047097          GFUI035780
# 11                 NaN                 NaN          GFUI035786
# 12                 NaN                 NaN          GFUI051070
# 13                 NaN                 NaN                 NaN
# 14                 NaN                 NaN                 NaN
# 15                 NaN                 NaN                 NaN
# 16                 NaN                 NaN                 NaN
# 17                 NaN                 NaN                 NaN
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23                 NaN                 NaN                 NaN
#
#    linked OR original one OR other NOT both
# 0          GFUI002713            GFUI002713
# 1          GFUI002898            GFUI002898
# 2          GFUI007441            GFUI007441
# 3          GFUI008017            GFUI008017
# 4          GFUI008024            GFUI008024
# 5          GFUI008496            GFUI008496
# 6          GFUI011907            GFUI011907
# 7          GFUI017734            GFUI017734
# 8          GFUI021833            GFUI021833
# 9          GFUI021834            GFUI021834
# 10         GFUI021857            GFUI021857
# 11         GFUI024278            GFUI024278
# 12         GFUI026687            GFUI026687
# 13         GFUI026699            GFUI026699
# 14         GFUI028910            GFUI028910
# 15         GFUI029720            GFUI029720
# 16         GFUI030741            GFUI030741
# 17         GFUI030748            GFUI030748
# 18         GFUI030827            GFUI030827
# 19         GFUI035775            GFUI035775
# 20         GFUI035780            GFUI035780
# 21         GFUI035786            GFUI035786
# 22         GFUI047097            GFUI047097
# 23         GFUI051070            GFUI051070

# %% [markdown]
# ## Novel Tx

# %%
novel = set_comparison_table(a=linked_wk_novel_tx, 
                             b=orig_wk_novel_tx,
                             a_name="linked", 
                             b_name="original")

# %%
novel['counts']
# Out:
#                        count
# linked AND original        0
# linked NOT original       19
# original NOT linked       20
# linked OR original        39
# one OR other NOT both     39

# %%
novel['genes']
# Out:
#    linked AND original linked NOT original original NOT linked  \
# 0                  NaN      TCONS_00031593      TCONS_00012154
# 1                  NaN      TCONS_00034477      TCONS_00032167
# 2                  NaN      TCONS_00034478      TCONS_00032172
# 3                  NaN      TCONS_00034479      TCONS_00032173
# 4                  NaN      TCONS_00034480      TCONS_00032174
# 5                  NaN      TCONS_00034481      TCONS_00032175
# 6                  NaN      TCONS_00034482      TCONS_00032176
# 7                  NaN      TCONS_00034483      TCONS_00032177
# 8                  NaN      TCONS_00034484      TCONS_00032877
# 9                  NaN      TCONS_00034485      TCONS_00032910
# 10                 NaN      TCONS_00034486      TCONS_00032911
# 11                 NaN      TCONS_00034487      TCONS_00032912
# 12                 NaN      TCONS_00034488      TCONS_00032913
# 13                 NaN      TCONS_00034489      TCONS_00032914
# 14                 NaN      TCONS_00034490      TCONS_00041433
# 15                 NaN      TCONS_00034491      TCONS_00041435
# 16                 NaN      TCONS_00034494      TCONS_00078898
# 17                 NaN      TCONS_00080293      TCONS_00078899
# 18                 NaN      TCONS_00080294      TCONS_00078900
# 19                 NaN                 NaN      TCONS_00079118
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 25                 NaN                 NaN                 NaN
# 26                 NaN                 NaN                 NaN
# 27                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 29                 NaN                 NaN                 NaN
# 30                 NaN                 NaN                 NaN
# 31                 NaN                 NaN                 NaN
# 32                 NaN                 NaN                 NaN
# 33                 NaN                 NaN                 NaN
# 34                 NaN                 NaN                 NaN
# 35                 NaN                 NaN                 NaN
# 36                 NaN                 NaN                 NaN
# 37                 NaN                 NaN                 NaN
# 38                 NaN                 NaN                 NaN
#
#    linked OR original one OR other NOT both
# 0      TCONS_00012154        TCONS_00012154
# 1      TCONS_00031593        TCONS_00031593
# 2      TCONS_00032167        TCONS_00032167
# 3      TCONS_00032172        TCONS_00032172
# 4      TCONS_00032173        TCONS_00032173
# 5      TCONS_00032174        TCONS_00032174
# 6      TCONS_00032175        TCONS_00032175
# 7      TCONS_00032176        TCONS_00032176
# 8      TCONS_00032177        TCONS_00032177
# 9      TCONS_00032877        TCONS_00032877
# 10     TCONS_00032910        TCONS_00032910
# 11     TCONS_00032911        TCONS_00032911
# 12     TCONS_00032912        TCONS_00032912
# 13     TCONS_00032913        TCONS_00032913
# 14     TCONS_00032914        TCONS_00032914
# 15     TCONS_00034477        TCONS_00034477
# 16     TCONS_00034478        TCONS_00034478
# 17     TCONS_00034479        TCONS_00034479
# 18     TCONS_00034480        TCONS_00034480
# 19     TCONS_00034481        TCONS_00034481
# 20     TCONS_00034482        TCONS_00034482
# 21     TCONS_00034483        TCONS_00034483
# 22     TCONS_00034484        TCONS_00034484
# 23     TCONS_00034485        TCONS_00034485
# 24     TCONS_00034486        TCONS_00034486
# 25     TCONS_00034487        TCONS_00034487
# 26     TCONS_00034488        TCONS_00034488
# 27     TCONS_00034489        TCONS_00034489
# 28     TCONS_00034490        TCONS_00034490
# 29     TCONS_00034491        TCONS_00034491
# 30     TCONS_00034494        TCONS_00034494
# 31     TCONS_00041433        TCONS_00041433
# 32     TCONS_00041435        TCONS_00041435
# 33     TCONS_00078898        TCONS_00078898
# 34     TCONS_00078899        TCONS_00078899
# 35     TCONS_00078900        TCONS_00078900
# 36     TCONS_00079118        TCONS_00079118
# 37     TCONS_00080293        TCONS_00080293
# 38     TCONS_00080294        TCONS_00080294
