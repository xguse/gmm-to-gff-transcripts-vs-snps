# %% [markdown]
# # Prep

# %% [markdown]
# ## Imports

# %%
# Load the "autoreload" extension
# %load_ext autoreload

# always reload modules marked with "%aimport"
# %autoreload 1

# %%
import sys
sys.path.append('../python/')

# %%
import pandas as pd

# %%
# %aimport linked_vs_orig
import linked_vs_orig as lvo

# %% [markdown]
# ## Paths

# %%
linked_ = '../data/processed/gmm_to_gff_testing_filterPSL_100bp_local/snps_near_homologous_de/snps_near_homologous_de_distance_0.linked.csv'
orig_ = '../data/processed/gmm_to_gff_testing_filterPSL_100bp_local/snps_near_homologous_de/snps_near_homologous_de_distance_0.original.csv'

# %% [markdown]
# ## Constants

# %%
# distance = 5000

# %% [markdown]
# ## Functions

# %% [markdown]
# ## Loading

# %%
linked = lvo.load_snps_near_de(linked_)
orig = lvo.load_snps_near_de(orig_)

# %%
linked.head()
# Out:
#      SNP_chrom  SNP_start  SNP_end      feature_set_name     proximal_id  \
# 0  Scaffold220     393448   393449       novel_mapped_tx  TCONS_00067396
# 1  Scaffold220     393448   393449       novel_mapped_tx  TCONS_00067396
# 2   Scaffold66     864875   864876  official_annotations      GFUI043720
# 3   Scaffold66     864875   864876  official_annotations      GFUI043720
# 4   Scaffold66     864875   864876  official_annotations      GFUI043720
#
#                         de_id      xloc_id        tcons_id gene_id_external  \
# 0  EDGR|PV_PLUS_MINUS_0000471  XLOC_033654  TCONS_00067396       GMOY009338
# 1   EDGR|PV_PLUS_PLUS_0001028  XLOC_033654  TCONS_00067396       GMOY009338
# 2         EDGR|MIDGUT_0001058  XLOC_027003  TCONS_00054385       GMOY007600
# 3         EDGR|MIDGUT_0001235  XLOC_026998  TCONS_00054371       GMOY007600
# 4         EDGR|MIDGUT_0001235  XLOC_026998  TCONS_00054372       GMOY007600
#
#   gene_id_internal    lg2_fc             p           fdr     comparison  \
# 0       GFUI016885  0.926871  1.649361e-06  4.325808e-05  PV_PLUS_MINUS
# 1       GFUI016885  0.685038  3.870522e-04  4.651028e-03   PV_PLUS_PLUS
# 2       GFUI043720  1.935130  7.147837e-09  7.425508e-08         MIDGUT
# 3       GFUI043720  1.647630  3.283071e-08  2.921800e-07         MIDGUT
# 4       GFUI043720  1.647630  3.283071e-08  2.921800e-07         MIDGUT
#
#   program                                                url
# 0   edger  https://www.vectorbase.org/Glossina_fuscipes/L...
# 1   edger  https://www.vectorbase.org/Glossina_fuscipes/L...
# 2   edger  https://www.vectorbase.org/Glossina_fuscipes/L...
# 3   edger  https://www.vectorbase.org/Glossina_fuscipes/L...
# 4   edger  https://www.vectorbase.org/Glossina_fuscipes/L...

# %%
orig.head()
# Out:
#     SNP_chrom  SNP_start  SNP_end      feature_set_name proximal_id  \
# 0  Scaffold27     960004   960005  official_annotations  GFUI021833
# 1  Scaffold27     960004   960005  official_annotations  GFUI021833
# 2  Scaffold27     960004   960005  official_annotations  GFUI021833
# 3  Scaffold27     960004   960005  official_annotations  GFUI021833
# 4  Scaffold27     960391   960392  official_annotations  GFUI021833
#
#                  de_id      xloc_id        tcons_id gene_id_external  \
# 0  EDGR|MIDGUT_0001618  XLOC_038726  TCONS_00080297       GMOY011124
# 1  EDGR|MIDGUT_0001618  XLOC_038726  TCONS_00080298       GMOY011124
# 2  EDGR|MIDGUT_0001618  XLOC_038726  TCONS_00080299       GMOY011124
# 3  EDGR|MIDGUT_0001618  XLOC_038726  TCONS_00080300       GMOY011124
# 4  EDGR|MIDGUT_0001618  XLOC_038726  TCONS_00080297       GMOY011124
#
#   gene_id_internal    lg2_fc             p       fdr comparison program  \
# 0       GFUI021833  2.735993  6.130982e-07  0.000004     MIDGUT   edger
# 1       GFUI021833  2.735993  6.130982e-07  0.000004     MIDGUT   edger
# 2       GFUI021833  2.735993  6.130982e-07  0.000004     MIDGUT   edger
# 3       GFUI021833  2.735993  6.130982e-07  0.000004     MIDGUT   edger
# 4       GFUI021833  2.735993  6.130982e-07  0.000004     MIDGUT   edger
#
#                                                  url
# 0  https://www.vectorbase.org/Glossina_fuscipes/L...
# 1  https://www.vectorbase.org/Glossina_fuscipes/L...
# 2  https://www.vectorbase.org/Glossina_fuscipes/L...
# 3  https://www.vectorbase.org/Glossina_fuscipes/L...
# 4  https://www.vectorbase.org/Glossina_fuscipes/L...

# %% [markdown]
# ## Cleaning

# %% [markdown]
# # Comparisons

# %%
# get sets of gene names to compare
split_linked = lvo.split_official_novel(linked)
split_orig = lvo.split_official_novel(orig)

# %% [markdown]
# ## Official Genes

# %%
official = lvo.set_comparison_table(a=split_linked.official_genes, 
                                    b=split_orig.official_genes,
                                    a_name="linked", 
                                    b_name="original")

# %%
split_linked.official_genes == split_orig.official_genes
# Out:
# False

# %%
official.counts
# Out:
#                        count
# linked                     7
# original                  11
# linked AND original        6
# linked NOT original        1
# original NOT linked        5
# linked OR original        12
# one OR other NOT both      6

# %%
official.genes
# Out:
#         linked    original linked AND original linked NOT original  \
# 0   GFUI002252  GFUI002252          GFUI002252          GFUI043025
# 1   GFUI021833  GFUI007441          GFUI021833                 NaN
# 2   GFUI030827  GFUI020790          GFUI030827                 NaN
# 3   GFUI041241  GFUI021833          GFUI041241                 NaN
# 4   GFUI043025  GFUI023751          GFUI043720                 NaN
# 5   GFUI043720  GFUI030827          GFUI051070                 NaN
# 6   GFUI051070  GFUI041241                 NaN                 NaN
# 7          NaN  GFUI043027                 NaN                 NaN
# 8          NaN  GFUI043720                 NaN                 NaN
# 9          NaN  GFUI051070                 NaN                 NaN
# 10         NaN  GFUI053401                 NaN                 NaN
# 11         NaN         NaN                 NaN                 NaN
#
#    original NOT linked linked OR original one OR other NOT both
# 0           GFUI007441         GFUI002252            GFUI007441
# 1           GFUI020790         GFUI007441            GFUI020790
# 2           GFUI023751         GFUI020790            GFUI023751
# 3           GFUI043027         GFUI021833            GFUI043025
# 4           GFUI053401         GFUI023751            GFUI043027
# 5                  NaN         GFUI030827            GFUI053401
# 6                  NaN         GFUI041241                   NaN
# 7                  NaN         GFUI043025                   NaN
# 8                  NaN         GFUI043027                   NaN
# 9                  NaN         GFUI043720                   NaN
# 10                 NaN         GFUI051070                   NaN
# 11                 NaN         GFUI053401                   NaN

# %% [markdown]
# ## Novel Tx

# %%
split_orig.novel_tx
# Out:
# {'TCONS_00039298',
#  'TCONS_00039299',
#  'TCONS_00039300',
#  'TCONS_00039301',
#  'TCONS_00067396',
#  'TCONS_00067903',
#  'TCONS_00067904',
#  'TCONS_00067905',
#  'TCONS_00067906',
#  'TCONS_00067907',
#  'TCONS_00067908',
#  'TCONS_00067909',
#  'TCONS_00067910',
#  'TCONS_00067911',
#  'TCONS_00067912'}

# %%
split_linked.novel_tx
# Out:
# {'TCONS_00034477',
#  'TCONS_00034478',
#  'TCONS_00034479',
#  'TCONS_00034480',
#  'TCONS_00034481',
#  'TCONS_00034482',
#  'TCONS_00034483',
#  'TCONS_00034484',
#  'TCONS_00034485',
#  'TCONS_00034486',
#  'TCONS_00034487',
#  'TCONS_00034488',
#  'TCONS_00034489',
#  'TCONS_00034490',
#  'TCONS_00034491',
#  'TCONS_00034494',
#  'TCONS_00039298',
#  'TCONS_00039299',
#  'TCONS_00039300',
#  'TCONS_00039301',
#  'TCONS_00067396',
#  'TCONS_00067903',
#  'TCONS_00067904',
#  'TCONS_00067905',
#  'TCONS_00067906',
#  'TCONS_00067907',
#  'TCONS_00067908',
#  'TCONS_00067909',
#  'TCONS_00067910',
#  'TCONS_00067911',
#  'TCONS_00067912'}

# %%
novel = lvo.set_comparison_table(a=split_linked.novel_tx, 
                             b=split_orig.novel_tx,
                             a_name="linked", 
                             b_name="original")

# %%
novel.counts
# Out:
#                        count
# linked                    31
# original                  15
# linked AND original       15
# linked NOT original       16
# original NOT linked        0
# linked OR original        31
# one OR other NOT both     16

# %%
novel.genes
# Out:
#             linked        original linked AND original linked NOT original  \
# 0   TCONS_00034477  TCONS_00039298      TCONS_00039298      TCONS_00034477
# 1   TCONS_00034478  TCONS_00039299      TCONS_00039299      TCONS_00034478
# 2   TCONS_00034479  TCONS_00039300      TCONS_00039300      TCONS_00034479
# 3   TCONS_00034480  TCONS_00039301      TCONS_00039301      TCONS_00034480
# 4   TCONS_00034481  TCONS_00067396      TCONS_00067396      TCONS_00034481
# 5   TCONS_00034482  TCONS_00067903      TCONS_00067903      TCONS_00034482
# 6   TCONS_00034483  TCONS_00067904      TCONS_00067904      TCONS_00034483
# 7   TCONS_00034484  TCONS_00067905      TCONS_00067905      TCONS_00034484
# 8   TCONS_00034485  TCONS_00067906      TCONS_00067906      TCONS_00034485
# 9   TCONS_00034486  TCONS_00067907      TCONS_00067907      TCONS_00034486
# 10  TCONS_00034487  TCONS_00067908      TCONS_00067908      TCONS_00034487
# 11  TCONS_00034488  TCONS_00067909      TCONS_00067909      TCONS_00034488
# 12  TCONS_00034489  TCONS_00067910      TCONS_00067910      TCONS_00034489
# 13  TCONS_00034490  TCONS_00067911      TCONS_00067911      TCONS_00034490
# 14  TCONS_00034491  TCONS_00067912      TCONS_00067912      TCONS_00034491
# 15  TCONS_00034494             NaN                 NaN      TCONS_00034494
# 16  TCONS_00039298             NaN                 NaN                 NaN
# 17  TCONS_00039299             NaN                 NaN                 NaN
# 18  TCONS_00039300             NaN                 NaN                 NaN
# 19  TCONS_00039301             NaN                 NaN                 NaN
# 20  TCONS_00067396             NaN                 NaN                 NaN
# 21  TCONS_00067903             NaN                 NaN                 NaN
# 22  TCONS_00067904             NaN                 NaN                 NaN
# 23  TCONS_00067905             NaN                 NaN                 NaN
# 24  TCONS_00067906             NaN                 NaN                 NaN
# 25  TCONS_00067907             NaN                 NaN                 NaN
# 26  TCONS_00067908             NaN                 NaN                 NaN
# 27  TCONS_00067909             NaN                 NaN                 NaN
# 28  TCONS_00067910             NaN                 NaN                 NaN
# 29  TCONS_00067911             NaN                 NaN                 NaN
# 30  TCONS_00067912             NaN                 NaN                 NaN
#
#    original NOT linked linked OR original one OR other NOT both
# 0                  NaN     TCONS_00034477        TCONS_00034477
# 1                  NaN     TCONS_00034478        TCONS_00034478
# 2                  NaN     TCONS_00034479        TCONS_00034479
# 3                  NaN     TCONS_00034480        TCONS_00034480
# 4                  NaN     TCONS_00034481        TCONS_00034481
# 5                  NaN     TCONS_00034482        TCONS_00034482
# 6                  NaN     TCONS_00034483        TCONS_00034483
# 7                  NaN     TCONS_00034484        TCONS_00034484
# 8                  NaN     TCONS_00034485        TCONS_00034485
# 9                  NaN     TCONS_00034486        TCONS_00034486
# 10                 NaN     TCONS_00034487        TCONS_00034487
# 11                 NaN     TCONS_00034488        TCONS_00034488
# 12                 NaN     TCONS_00034489        TCONS_00034489
# 13                 NaN     TCONS_00034490        TCONS_00034490
# 14                 NaN     TCONS_00034491        TCONS_00034491
# 15                 NaN     TCONS_00034494        TCONS_00034494
# 16                 NaN     TCONS_00039298                   NaN
# 17                 NaN     TCONS_00039299                   NaN
# 18                 NaN     TCONS_00039300                   NaN
# 19                 NaN     TCONS_00039301                   NaN
# 20                 NaN     TCONS_00067396                   NaN
# 21                 NaN     TCONS_00067903                   NaN
# 22                 NaN     TCONS_00067904                   NaN
# 23                 NaN     TCONS_00067905                   NaN
# 24                 NaN     TCONS_00067906                   NaN
# 25                 NaN     TCONS_00067907                   NaN
# 26                 NaN     TCONS_00067908                   NaN
# 27                 NaN     TCONS_00067909                   NaN
# 28                 NaN     TCONS_00067910                   NaN
# 29                 NaN     TCONS_00067911                   NaN
# 30                 NaN     TCONS_00067912                   NaN

# %% [markdown]
# # New proximal_id from LINKED

# %%
new_novel = split_linked.novel_tx - split_orig.novel_tx
new_official = split_linked.official_genes - split_orig.official_genes

# %%
new_prox_ids = list(new_novel) + list(new_official)

# %%
linked_new = linked[linked.proximal_id.isin(new_prox_ids)]

# %%
linked_new.shape
# Out:
# (104, 16)

# %%
linked_new
# Out:
#       SNP_chrom  SNP_start  SNP_end      feature_set_name     proximal_id  \
# 70   Scaffold64     732108   732109  official_annotations      GFUI043025
# 71   Scaffold64     732108   732109  official_annotations      GFUI043025
# 72   Scaffold64     732108   732109  official_annotations      GFUI043025
# 73   Scaffold64     732119   732120  official_annotations      GFUI043025
# 74   Scaffold64     732119   732120  official_annotations      GFUI043025
# 75   Scaffold64     732119   732120  official_annotations      GFUI043025
# 76   Scaffold64     732121   732122  official_annotations      GFUI043025
# 77   Scaffold64     732121   732122  official_annotations      GFUI043025
# 78   Scaffold64     732121   732122  official_annotations      GFUI043025
# 79   Scaffold64     732173   732174  official_annotations      GFUI043025
# 80   Scaffold64     732173   732174  official_annotations      GFUI043025
# 81   Scaffold64     732173   732174  official_annotations      GFUI043025
# 82   Scaffold64     732108   732109  official_annotations      GFUI043025
# 83   Scaffold64     732108   732109  official_annotations      GFUI043025
# 84   Scaffold64     732108   732109  official_annotations      GFUI043025
# 85   Scaffold64     732119   732120  official_annotations      GFUI043025
# 86   Scaffold64     732119   732120  official_annotations      GFUI043025
# 87   Scaffold64     732119   732120  official_annotations      GFUI043025
# 88   Scaffold64     732121   732122  official_annotations      GFUI043025
# 89   Scaffold64     732121   732122  official_annotations      GFUI043025
# 90   Scaffold64     732121   732122  official_annotations      GFUI043025
# 91   Scaffold64     732173   732174  official_annotations      GFUI043025
# 92   Scaffold64     732173   732174  official_annotations      GFUI043025
# 93   Scaffold64     732173   732174  official_annotations      GFUI043025
# 100  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034486
# 101  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034487
# 102  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034488
# 103  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034489
# 104  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034485
# 105  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034484
# ..          ...        ...      ...                   ...             ...
# 150  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034488
# 151  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034489
# 152  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034485
# 153  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034484
# 154  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034483
# 155  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034480
# 156  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034481
# 157  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034494
# 158  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034477
# 159  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034482
# 160  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034479
# 161  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034490
# 162  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034491
# 163  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034478
# 164  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034486
# 165  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034487
# 166  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034488
# 167  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034489
# 168  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034485
# 169  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034484
# 170  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034483
# 171  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034480
# 172  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034481
# 173  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034494
# 174  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034477
# 175  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034482
# 176  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034479
# 177  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034490
# 178  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034491
# 179  Scaffold22    1291804  1291805       novel_mapped_tx  TCONS_00034478
#
#                           de_id      xloc_id        tcons_id gene_id_external  \
# 70          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041812       GMOY005879
# 71          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041813       GMOY005879
# 72          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041814       GMOY005879
# 73          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041812       GMOY005879
# 74          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041813       GMOY005879
# 75          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041814       GMOY005879
# 76          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041812       GMOY005879
# 77          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041813       GMOY005879
# 78          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041814       GMOY005879
# 79          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041812       GMOY005879
# 80          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041813       GMOY005879
# 81          EDGR|MIDGUT_0003725  XLOC_020485  TCONS_00041814       GMOY005879
# 82          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041812       GMOY005879
# 83          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041813       GMOY005879
# 84          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041814       GMOY005879
# 85          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041812       GMOY005879
# 86          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041813       GMOY005879
# 87          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041814       GMOY005879
# 88          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041812       GMOY005879
# 89          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041813       GMOY005879
# 90          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041814       GMOY005879
# 91          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041812       GMOY005879
# 92          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041813       GMOY005879
# 93          CUFF|MIDGUT_0002490  XLOC_020485  TCONS_00041814       GMOY005879
# 100  EDGR|PV_PLUS_MINUS_0000719  XLOC_016800  TCONS_00034486       GMOY004806
# 101  EDGR|PV_PLUS_MINUS_0000719  XLOC_016800  TCONS_00034487       GMOY004806
# 102  EDGR|PV_PLUS_MINUS_0000719  XLOC_016800  TCONS_00034488       GMOY004806
# 103  EDGR|PV_PLUS_MINUS_0000719  XLOC_016800  TCONS_00034489       GMOY004806
# 104  EDGR|PV_PLUS_MINUS_0000719  XLOC_016800  TCONS_00034485       GMOY004806
# 105  EDGR|PV_PLUS_MINUS_0000719  XLOC_016800  TCONS_00034484       GMOY004806
# ..                          ...          ...             ...              ...
# 150  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034488       GMOY004806
# 151  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034489       GMOY004806
# 152  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034485       GMOY004806
# 153  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034484       GMOY004806
# 154  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034483       GMOY004806
# 155  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034480       GMOY004806
# 156  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034481       GMOY004806
# 157  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034494       GMOY004806
# 158  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034477       GMOY004806
# 159  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034482       GMOY004806
# 160  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034479       GMOY004806
# 161  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034490       GMOY004806
# 162  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034491       GMOY004806
# 163  CUFF|PV_PLUS_MINUS_0000501  XLOC_016800  TCONS_00034478       GMOY004806
# 164   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034486       GMOY004806
# 165   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034487       GMOY004806
# 166   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034488       GMOY004806
# 167   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034489       GMOY004806
# 168   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034485       GMOY004806
# 169   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034484       GMOY004806
# 170   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034483       GMOY004806
# 171   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034480       GMOY004806
# 172   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034481       GMOY004806
# 173   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034494       GMOY004806
# 174   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034477       GMOY004806
# 175   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034482       GMOY004806
# 176   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034479       GMOY004806
# 177   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034490       GMOY004806
# 178   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034491       GMOY004806
# 179   CUFF|PV_PLUS_PLUS_0000691  XLOC_016800  TCONS_00034478       GMOY004806
#
#     gene_id_internal    lg2_fc         p       fdr     comparison    program  \
# 70        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 71        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 72        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 73        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 74        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 75        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 76        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 77        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 78        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 79        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 80        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 81        GFUI043025 -0.790157  0.001578  0.004656         MIDGUT      edger
# 82        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 83        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 84        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 85        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 86        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 87        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 88        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 89        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 90        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 91        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 92        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 93        GFUI043025 -1.244290  0.000050  0.000224         MIDGUT  cufflinks
# 100       GFUI017734  0.632797  0.000050  0.000863  PV_PLUS_MINUS      edger
# 101       GFUI017734  0.632797  0.000050  0.000863  PV_PLUS_MINUS      edger
# 102       GFUI017734  0.632797  0.000050  0.000863  PV_PLUS_MINUS      edger
# 103       GFUI017734  0.632797  0.000050  0.000863  PV_PLUS_MINUS      edger
# 104       GFUI017734  0.632797  0.000050  0.000863  PV_PLUS_MINUS      edger
# 105       GFUI017734  0.632797  0.000050  0.000863  PV_PLUS_MINUS      edger
# ..               ...       ...       ...       ...            ...        ...
# 150       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 151       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 152       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 153       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 154       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 155       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 156       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 157       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 158       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 159       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 160       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 161       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 162       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 163       GFUI017734  0.578987  0.000050  0.001069  PV_PLUS_MINUS  cufflinks
# 164       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 165       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 166       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 167       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 168       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 169       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 170       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 171       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 172       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 173       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 174       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 175       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 176       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 177       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 178       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
# 179       GFUI017734  0.592747  0.000050  0.001100   PV_PLUS_PLUS  cufflinks
#
#                                                    url
# 70   https://www.vectorbase.org/Glossina_fuscipes/L...
# 71   https://www.vectorbase.org/Glossina_fuscipes/L...
# 72   https://www.vectorbase.org/Glossina_fuscipes/L...
# 73   https://www.vectorbase.org/Glossina_fuscipes/L...
# 74   https://www.vectorbase.org/Glossina_fuscipes/L...
# 75   https://www.vectorbase.org/Glossina_fuscipes/L...
# 76   https://www.vectorbase.org/Glossina_fuscipes/L...
# 77   https://www.vectorbase.org/Glossina_fuscipes/L...
# 78   https://www.vectorbase.org/Glossina_fuscipes/L...
# 79   https://www.vectorbase.org/Glossina_fuscipes/L...
# 80   https://www.vectorbase.org/Glossina_fuscipes/L...
# 81   https://www.vectorbase.org/Glossina_fuscipes/L...
# 82   https://www.vectorbase.org/Glossina_fuscipes/L...
# 83   https://www.vectorbase.org/Glossina_fuscipes/L...
# 84   https://www.vectorbase.org/Glossina_fuscipes/L...
# 85   https://www.vectorbase.org/Glossina_fuscipes/L...
# 86   https://www.vectorbase.org/Glossina_fuscipes/L...
# 87   https://www.vectorbase.org/Glossina_fuscipes/L...
# 88   https://www.vectorbase.org/Glossina_fuscipes/L...
# 89   https://www.vectorbase.org/Glossina_fuscipes/L...
# 90   https://www.vectorbase.org/Glossina_fuscipes/L...
# 91   https://www.vectorbase.org/Glossina_fuscipes/L...
# 92   https://www.vectorbase.org/Glossina_fuscipes/L...
# 93   https://www.vectorbase.org/Glossina_fuscipes/L...
# 100  https://www.vectorbase.org/Glossina_fuscipes/L...
# 101  https://www.vectorbase.org/Glossina_fuscipes/L...
# 102  https://www.vectorbase.org/Glossina_fuscipes/L...
# 103  https://www.vectorbase.org/Glossina_fuscipes/L...
# 104  https://www.vectorbase.org/Glossina_fuscipes/L...
# 105  https://www.vectorbase.org/Glossina_fuscipes/L...
# ..                                                 ...
# 150  https://www.vectorbase.org/Glossina_fuscipes/L...
# 151  https://www.vectorbase.org/Glossina_fuscipes/L...
# 152  https://www.vectorbase.org/Glossina_fuscipes/L...
# 153  https://www.vectorbase.org/Glossina_fuscipes/L...
# 154  https://www.vectorbase.org/Glossina_fuscipes/L...
# 155  https://www.vectorbase.org/Glossina_fuscipes/L...
# 156  https://www.vectorbase.org/Glossina_fuscipes/L...
# 157  https://www.vectorbase.org/Glossina_fuscipes/L...
# 158  https://www.vectorbase.org/Glossina_fuscipes/L...
# 159  https://www.vectorbase.org/Glossina_fuscipes/L...
# 160  https://www.vectorbase.org/Glossina_fuscipes/L...
# 161  https://www.vectorbase.org/Glossina_fuscipes/L...
# 162  https://www.vectorbase.org/Glossina_fuscipes/L...
# 163  https://www.vectorbase.org/Glossina_fuscipes/L...
# 164  https://www.vectorbase.org/Glossina_fuscipes/L...
# 165  https://www.vectorbase.org/Glossina_fuscipes/L...
# 166  https://www.vectorbase.org/Glossina_fuscipes/L...
# 167  https://www.vectorbase.org/Glossina_fuscipes/L...
# 168  https://www.vectorbase.org/Glossina_fuscipes/L...
# 169  https://www.vectorbase.org/Glossina_fuscipes/L...
# 170  https://www.vectorbase.org/Glossina_fuscipes/L...
# 171  https://www.vectorbase.org/Glossina_fuscipes/L...
# 172  https://www.vectorbase.org/Glossina_fuscipes/L...
# 173  https://www.vectorbase.org/Glossina_fuscipes/L...
# 174  https://www.vectorbase.org/Glossina_fuscipes/L...
# 175  https://www.vectorbase.org/Glossina_fuscipes/L...
# 176  https://www.vectorbase.org/Glossina_fuscipes/L...
# 177  https://www.vectorbase.org/Glossina_fuscipes/L...
# 178  https://www.vectorbase.org/Glossina_fuscipes/L...
# 179  https://www.vectorbase.org/Glossina_fuscipes/L...
#
# [104 rows x 16 columns]
