# %% [markdown]
# # Prep

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Paths

# %%
linked_ = '../data/processed/gmm_to_gff_testing_filterPSL_100bp_local/get_nearest_k_features/NB.linked.snps_in_features.xls'
orig_ = '../data/processed/gmm_to_gff_testing_filterPSL_100bp_local/get_nearest_k_features/NB.original.snps_in_features.xls'

# %% [markdown]
# ## Constants

# %%
distance = 5000

# %% [markdown]
# ## Functions

# %%
def filter_by_distance(df, d=5000):
    return df.query(""" abs(distance) <= {d} """.format(d=d))

def set_comparison_table(a, b, a_name=None, b_name=None):
    a = set(a)
    b = set(b)
    
    data = [pd.Series((sorted(list(a & b))),name='{a} AND {b}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(a - b))),name='{a} NOT {b}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(b - a))),name='{b} NOT {a}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(a | b))),name='{a} OR {b}'.format(a=a_name,b=b_name)),
            pd.Series((sorted(list(a ^ b))),name='one OR other NOT both'),]
    
    df = pd.DataFrame(data).T
    counts = pd.DataFrame(df.count(),columns=['count'])
    
    return {'genes':df, 'counts':counts}

# %% [markdown]
# ## Loading

# %%
linked = pd.read_excel(linked_)
orig = pd.read_excel(orig_)

# %%
linked.head()
# Out:
#    SNP_chrom  SNP_start  SNP_end feature_set_name      chrom  chromStart  \
# 0  Scaffold1    2237682  2237683  novel_mapped_tx  Scaffold1     2226915
# 1  Scaffold1    2237682  2237683  novel_mapped_tx  Scaffold1     2268286
# 2  Scaffold1    2237682  2237683  novel_mapped_tx  Scaffold1     2144078
# 3  Scaffold1    2237682  2237683  novel_mapped_tx  Scaffold1     2365004
# 4  Scaffold1    2237682  2237683  novel_mapped_tx  Scaffold1     2108451
#
#    chromEnd            name  score strand thickStart thickEnd itemRgb  \
# 0   2227788  TCONS_00023667      0      -    2226915  2227788   0,0,0
# 1   2268509  TCONS_00023697      0      +    2268286  2268509   0,0,0
# 2   2165341  TCONS_00038064      0      -    2144078  2165341   0,0,0
# 3   2365581  TCONS_00071717      0      -    2365004  2365581   0,0,0
# 4   2108494  TCONS_00038070      0      +    2108451  2110472   0,0,0
#
#   blockCount                                  blockSizes  \
# 0          4                            216,114,281,260,
# 1          3                                  52,16,140,
# 2         15  60,11,41,73,101,19,12,17,80,99,6,6,7,7,49,
# 3         11           55,21,49,21,48,55,4,153,13,5,115,
# 4          6                      317,510,186,531,13,21,
#
#                                          blockStarts  distance
# 0                   2226915,2227133,2227247,2227528,     -9895
# 1                           2268286,2268345,2268369,     30604
# 2  2144078,2164656,2164669,2164712,2164785,216488...    -72342
# 3  2365004,2365062,2365083,2365134,2365161,236521...    127322
# 4   2108451,2108864,2109663,2109906,2110437,2110451,   -129189

# %%
orig.head()
# Out:
#      SNP_chrom  SNP_start  SNP_end feature_set_name        chrom  chromStart  \
# 0  Scaffold102     326971   326972  novel_mapped_tx  Scaffold102      365118
# 1  Scaffold102     326971   326972  novel_mapped_tx  Scaffold102      365118
# 2  Scaffold102     326971   326972  novel_mapped_tx  Scaffold102      410767
# 3  Scaffold102     326971   326972  novel_mapped_tx  Scaffold102      410878
# 4  Scaffold102     326971   326972  novel_mapped_tx  Scaffold102      410878
#
#    chromEnd            name  score strand  thickStart  thickEnd itemRgb  \
# 0    365134  TCONS_00081556      0      -      361821    365134   0,0,0
# 1    365134  TCONS_00083794      0      +      361821    365134   0,0,0
# 2    410831  TCONS_00083793      0      +      402801    410831   0,0,0
# 3    415275  TCONS_00081530      0      -      410878    446526   0,0,0
# 4    415275  TCONS_00081531      0      -      410878    446526   0,0,0
#
#    blockCount                                         blockSizes  \
# 0          16  31,104,231,237,4,19,19,169,391,346,104,180,515...
# 1          16  31,104,25,96,224,4,19,16,172,391,346,104,180,1...
# 2          24  69,31,24,57,54,115,13,55,899,194,545,921,490,5...
# 3          93  10,6,40,34,15,6,41,23,39,8,85,4,130,62,199,14,...
# 4          93  10,6,40,34,15,6,41,23,39,8,85,4,130,62,199,14,...
#
#                                          blockStarts  distance
# 0  361821,361855,361959,362209,362447,362451,3624...     38147
# 1  361821,361855,361959,362054,362222,362447,3624...     38147
# 2  402801,402881,402917,402950,403007,403071,4038...     83796
# 3  410878,410888,410897,410943,410977,411011,4110...     83907
# 4  410878,410888,410897,410943,410977,411011,4110...     83907

# %% [markdown]
# ## Cleaning

# %%
linked_wk = filter_by_distance(df=linked, d=distance)
orig_wk = filter_by_distance(df=orig, d=distance)

# %%
linked_wk.shape
# Out:
# (38, 17)

# %%
orig_wk.shape
# Out:
# (105, 17)

# %% [markdown]
# # Comparisons

# %%
# get sets of gene names to compare

linked_wk_official_genes = set(linked_wk.query(""" feature_set_name == 'official_annotations' """).name)
linked_wk_novel_tx = set(linked_wk.query(""" feature_set_name == 'novel_mapped_tx' """).name)

orig_wk_official_genes = set(orig_wk.query(""" feature_set_name == 'official_annotations' """).name)
orig_wk_novel_tx = set(orig_wk.query(""" feature_set_name == 'novel_mapped_tx' """).name)

# %% [markdown]
# ## Official Genes

# %%
official = set_comparison_table(a=linked_wk_official_genes, 
                                b=orig_wk_official_genes,
                                a_name="linked", 
                                b_name="original")

# %%
official['counts']
# Out:
#                        count
# linked AND original        0
# linked NOT original       13
# original NOT linked       18
# linked OR original        31
# one OR other NOT both     31

# %%
official['genes']
# Out:
#    linked AND original linked NOT original original NOT linked  \
# 0                  NaN          GFUI008496          GFUI002233
# 1                  NaN          GFUI011907          GFUI002250
# 2                  NaN          GFUI026687          GFUI002252
# 3                  NaN          GFUI026692          GFUI002256
# 4                  NaN          GFUI026694          GFUI003051
# 5                  NaN          GFUI026699          GFUI003053
# 6                  NaN          GFUI029720          GFUI007952
# 7                  NaN          GFUI035775          GFUI009421
# 8                  NaN          GFUI035780          GFUI019498
# 9                  NaN          GFUI035784          GFUI019501
# 10                 NaN          GFUI035786          GFUI023675
# 11                 NaN          GFUI035806          GFUI026464
# 12                 NaN          GFUI051070          GFUI026466
# 13                 NaN                 NaN          GFUI026467
# 14                 NaN                 NaN          GFUI041241
# 15                 NaN                 NaN          GFUI041245
# 16                 NaN                 NaN          GFUI043916
# 17                 NaN                 NaN          GFUI053502
# 18                 NaN                 NaN                 NaN
# 19                 NaN                 NaN                 NaN
# 20                 NaN                 NaN                 NaN
# 21                 NaN                 NaN                 NaN
# 22                 NaN                 NaN                 NaN
# 23                 NaN                 NaN                 NaN
# 24                 NaN                 NaN                 NaN
# 25                 NaN                 NaN                 NaN
# 26                 NaN                 NaN                 NaN
# 27                 NaN                 NaN                 NaN
# 28                 NaN                 NaN                 NaN
# 29                 NaN                 NaN                 NaN
# 30                 NaN                 NaN                 NaN
#
#    linked OR original one OR other NOT both
# 0          GFUI002233            GFUI002233
# 1          GFUI002250            GFUI002250
# 2          GFUI002252            GFUI002252
# 3          GFUI002256            GFUI002256
# 4          GFUI003051            GFUI003051
# 5          GFUI003053            GFUI003053
# 6          GFUI007952            GFUI007952
# 7          GFUI008496            GFUI008496
# 8          GFUI009421            GFUI009421
# 9          GFUI011907            GFUI011907
# 10         GFUI019498            GFUI019498
# 11         GFUI019501            GFUI019501
# 12         GFUI023675            GFUI023675
# 13         GFUI026464            GFUI026464
# 14         GFUI026466            GFUI026466
# 15         GFUI026467            GFUI026467
# 16         GFUI026687            GFUI026687
# 17         GFUI026692            GFUI026692
# 18         GFUI026694            GFUI026694
# 19         GFUI026699            GFUI026699
# 20         GFUI029720            GFUI029720
# 21         GFUI035775            GFUI035775
# 22         GFUI035780            GFUI035780
# 23         GFUI035784            GFUI035784
# 24         GFUI035786            GFUI035786
# 25         GFUI035806            GFUI035806
# 26         GFUI041241            GFUI041241
# 27         GFUI041245            GFUI041245
# 28         GFUI043916            GFUI043916
# 29         GFUI051070            GFUI051070
# 30         GFUI053502            GFUI053502

# %% [markdown]
# ## Novel Tx

# %%
novel = set_comparison_table(a=linked_wk_novel_tx, 
                             b=orig_wk_novel_tx,
                             a_name="linked", 
                             b_name="original")

# %%
novel['counts']
# Out:
#                        count
# linked AND original        0
# linked NOT original        9
# original NOT linked       31
# linked OR original        40
# one OR other NOT both     40

# %%
novel['genes']
# Out:
#    linked AND original linked NOT original original NOT linked  \
# 0                  NaN      TCONS_00012154      TCONS_00023519
# 1                  NaN      TCONS_00032877      TCONS_00037543
# 2                  NaN      TCONS_00032910      TCONS_00037545
# 3                  NaN      TCONS_00032911      TCONS_00039298
# 4                  NaN      TCONS_00032912      TCONS_00039299
# 5                  NaN      TCONS_00032913      TCONS_00039300
# 6                  NaN      TCONS_00032914      TCONS_00039301
# 7                  NaN      TCONS_00041433      TCONS_00039303
# 8                  NaN      TCONS_00041435      TCONS_00048884
# 9                  NaN                 NaN      TCONS_00067903
# 10                 NaN                 NaN      TCONS_00067904
# 11                 NaN                 NaN      TCONS_00067905
# 12                 NaN                 NaN      TCONS_00067906
# 13                 NaN                 NaN      TCONS_00067907
# 14                 NaN                 NaN      TCONS_00067908
# 15                 NaN                 NaN      TCONS_00067909
# 16                 NaN                 NaN      TCONS_00067910
# 17                 NaN                 NaN      TCONS_00067911
# 18                 NaN                 NaN      TCONS_00067912
# 19                 NaN                 NaN      TCONS_00075476
# 20                 NaN                 NaN      TCONS_00075477
# 21                 NaN                 NaN      TCONS_00075478
# 22                 NaN                 NaN      TCONS_00075479
# 23                 NaN                 NaN      TCONS_00075480
# 24                 NaN                 NaN      TCONS_00075481
# 25                 NaN                 NaN      TCONS_00075484
# 26                 NaN                 NaN      TCONS_00075485
# 27                 NaN                 NaN      TCONS_00075486
# 28                 NaN                 NaN      TCONS_00075487
# 29                 NaN                 NaN      TCONS_00075488
# 30                 NaN                 NaN      TCONS_00075489
# 31                 NaN                 NaN                 NaN
# 32                 NaN                 NaN                 NaN
# 33                 NaN                 NaN                 NaN
# 34                 NaN                 NaN                 NaN
# 35                 NaN                 NaN                 NaN
# 36                 NaN                 NaN                 NaN
# 37                 NaN                 NaN                 NaN
# 38                 NaN                 NaN                 NaN
# 39                 NaN                 NaN                 NaN
#
#    linked OR original one OR other NOT both
# 0      TCONS_00012154        TCONS_00012154
# 1      TCONS_00023519        TCONS_00023519
# 2      TCONS_00032877        TCONS_00032877
# 3      TCONS_00032910        TCONS_00032910
# 4      TCONS_00032911        TCONS_00032911
# 5      TCONS_00032912        TCONS_00032912
# 6      TCONS_00032913        TCONS_00032913
# 7      TCONS_00032914        TCONS_00032914
# 8      TCONS_00037543        TCONS_00037543
# 9      TCONS_00037545        TCONS_00037545
# 10     TCONS_00039298        TCONS_00039298
# 11     TCONS_00039299        TCONS_00039299
# 12     TCONS_00039300        TCONS_00039300
# 13     TCONS_00039301        TCONS_00039301
# 14     TCONS_00039303        TCONS_00039303
# 15     TCONS_00041433        TCONS_00041433
# 16     TCONS_00041435        TCONS_00041435
# 17     TCONS_00048884        TCONS_00048884
# 18     TCONS_00067903        TCONS_00067903
# 19     TCONS_00067904        TCONS_00067904
# 20     TCONS_00067905        TCONS_00067905
# 21     TCONS_00067906        TCONS_00067906
# 22     TCONS_00067907        TCONS_00067907
# 23     TCONS_00067908        TCONS_00067908
# 24     TCONS_00067909        TCONS_00067909
# 25     TCONS_00067910        TCONS_00067910
# 26     TCONS_00067911        TCONS_00067911
# 27     TCONS_00067912        TCONS_00067912
# 28     TCONS_00075476        TCONS_00075476
# 29     TCONS_00075477        TCONS_00075477
# 30     TCONS_00075478        TCONS_00075478
# 31     TCONS_00075479        TCONS_00075479
# 32     TCONS_00075480        TCONS_00075480
# 33     TCONS_00075481        TCONS_00075481
# 34     TCONS_00075484        TCONS_00075484
# 35     TCONS_00075485        TCONS_00075485
# 36     TCONS_00075486        TCONS_00075486
# 37     TCONS_00075487        TCONS_00075487
# 38     TCONS_00075488        TCONS_00075488
# 39     TCONS_00075489        TCONS_00075489
